# %% [markdown]
# # Data Prep

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import f1_score, matthews_corrcoef

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

import psutil
import time
import logging
from datetime import datetime
import random
import os
import shutil
import itertools

import ray
from ray import tune
from ray.tune.schedulers import ASHAScheduler
from ray.air import session
from ray.tune.integration.keras import TuneReportCallback
from ray.tune.search.optuna import OptunaSearch
from ray.tune.tuner import Tuner, TuneConfig
from ray.train import RunConfig
from ray.tune import Trainable

import helper

# Initialize Ray
ray.init(ignore_reinit_error=True)

# Check if MPS (Apple Silicon) or CUDA (Nvidia) GPU is available
if torch.backends.mps.is_available():
    device = torch.device('mps')
elif torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print(f"Using device: {device}")
# Out:
# 2024-08-11 18:52:10,806	INFO worker.py:1772 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# Using device: mps

# %% [markdown]
# ## Existing Data Files Check

# %%
def clear_folder(folder_path):
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        if item == '.gitignore':
            continue
        if os.path.isfile(item_path):
            os.remove(item_path)
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)

clear_folder("ray_results")
clear_folder("outputs")
clear_folder("results")

# %% [markdown]
# ## Simple FNN

# %%
class Classic_FFN(nn.Module):
    def __init__(self, num_classes, hidden_layers=[30, 15], dropout_rate=0.5, activation='relu'):
        super(Classic_FFN, self).__init__()

        self.activation = activation

        # shared LSTM layers
        self.lstm_layers = nn.ModuleList()
        self.lstm_layers.append(nn.LSTM(input_size=1, hidden_size=64, batch_first=True))
        self.lstm_layers.append(nn.LSTM(input_size=64, hidden_size=128, batch_first=True))
        self.lstm_layers.append(nn.LSTM(input_size=128, hidden_size=256, batch_first=True))

        input_dim = 256

        self.shared_layers = nn.ModuleList()

        for hidden_layer in hidden_layers:
            self.shared_layers.append(nn.Linear(input_dim, hidden_layer))
            self.shared_layers.append(nn.Dropout(dropout_rate))
            input_dim = hidden_layer

        self.output_layer = nn.Linear(input_dim, num_classes)

    def forward(self, x):
        # Add input size dimension
        x = x.unsqueeze(-1)  # Shape: (batch_size, sequence_length, input_size)

        # Pass through LSTM layers
        for lstm in self.lstm_layers:
            x, _ = lstm(x)
        
        # Taking the output of the last time step
        x = x[:, -1, :]

        for layer in self.shared_layers:
            if isinstance(layer, nn.Linear):
                x = layer(x)
                x = self.apply_activation(x)
            elif isinstance(layer, nn.Dropout):
                x = layer(x)
            
        x = self.output_layer(x)
        return x

    def apply_activation(self, x):
        if self.activation == 'relu':
            return F.relu(x)
        elif self.activation == 'tanh':
            return torch.tanh(x)
        elif self.activation == 'sigmoid':
            return torch.sigmoid(x)
        else:
            raise ValueError(f'Invalid activation: {self.activation}')

# %%
def create_model(num_classes, hidden_layers=[30,15], dropout_rate=0.5, activation='relu'):
    model = Classic_FFN(num_classes=num_classes, hidden_layers=hidden_layers, dropout_rate=dropout_rate, activation=activation)
    model.to(device)  # Move the model to the selected device
    return model

def train(model, X_train, y_train, num_epochs, batch_size, learning_rate):
    # Convert data to PyTorch tensors and move to the selected device
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(np.argmax(y_train, axis=1), dtype=torch.long).to(device)  # Convert one-hot to class indices

    # Create a DataLoader for the training data
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    
    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    # Training loop
    for epoch in range(num_epochs):
        model.train()  # Set the model to training mode
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()  # Clear the gradients
            outputs = model(X_batch)  # Forward pass
            loss = criterion(outputs, y_batch)  # Calculate loss
            loss.backward()  # Backward pass
            optimizer.step()  # Update weights
    
    return model

def evaluate(model, X_test, y_test):
    # Convert data to PyTorch tensors and move to the selected device
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
    y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device)
    
    # Set model to evaluation mode
    model.eval()
    
    # Disable gradient calculation for inference
    with torch.no_grad():
        outputs = model(X_test_tensor)  # Forward pass
        y_pred_classes = torch.argmax(outputs, dim=1).cpu().numpy()  # Get predicted classes and move to CPU
        y_test_classes = torch.argmax(y_test_tensor, dim=1).cpu().numpy()  # Get true classes and move to CPU
        
        # Calculate accuracy
        accuracy = (y_pred_classes == y_test_classes).mean()
        
        # Calculate F1 scores and MCC
        f1_macro = f1_score(y_test_classes, y_pred_classes, average='macro')
        f1_micro = f1_score(y_test_classes, y_pred_classes, average='micro')
        mcc = matthews_corrcoef(y_test_classes, y_pred_classes)
    
    return accuracy, f1_macro, f1_micro, mcc

# %%
def evaluate_model_on_dataset_one_split(config, split, split_index):
    test_set = split[split_index]
    indices = [0, 1, 2, 3, 4]
    indices.remove(split_index)
    train_splits = [split[i] for i in indices]
    train_set = pd.concat(train_splits, axis=0)

    classes = train_set['track'].unique()
    num_classes = len(classes)
    #print("number of classes: " + str(num_classes))

    one_hot_columns = train_set['track'].unique()
    one_hot = pd.get_dummies(train_set['track'])
    train_set = train_set.drop('track', axis=1)
    train_set = train_set.join(one_hot).astype(float)

    one_hot_columns = test_set['track'].unique()
    one_hot = pd.get_dummies(test_set['track'])
    test_set = test_set.drop('track', axis=1)
    test_set = test_set.join(one_hot).astype(float)

    X_train = train_set.drop(columns=one_hot_columns).values.reshape(-1, 30)
    y_train = train_set[one_hot_columns].values.reshape(-1, num_classes)
    X_test = test_set.drop(columns=one_hot_columns).values.reshape(-1, 30)
    y_test = test_set[one_hot_columns].values.reshape(-1, num_classes)

    model = create_model(num_classes, activation=config['activation'], hidden_layers=config['hidden_layers'], dropout_rate=config['dropout_rate'])

    # Train the model and collect performance data
    model= train(model=model, X_train=X_train, y_train=y_train, num_epochs=config['epochs'], batch_size=config['batch_size'], learning_rate=config['learning_rate'])
    # Evaluate the model and collect performance data
    accuracy, f1_macro, f1_micro, mcc = evaluate(model=model, X_test=X_test, y_test=y_test)


    return accuracy, f1_macro, f1_micro, mcc, num_classes

# %% [markdown]
# ## 5-Fold-Cross Validation

# %%
df_data_spike_1_split = pd.DataFrame()
df_data_spike_full_split = pd.DataFrame()

data_spike_exec_1_split_dict = dict()
data_spike_exec_full_split_dict = dict()


best_params_list_getting = []

def custom_trial_dirname(trial):
    return f"trial_{trial.trial_id}"

# %%
def train_and_evaluate(config, splits, splits_name):
    
    global data_spike_exec_1_split_dict
    global data_spike_exec_full_split_dict
    global df_data_spike_1_split
    global results_dir
    
    min_accuracy = 1
    max_accuracy = 0
    avg_accuracy = 0
    min_f1_macro = 1
    max_f1_macro = 0
    avg_f1_macro = 0
    min_f1_micro = 1
    max_f1_micro = 0
    avg_f1_micro = 0
    min_mcc = 1
    max_mcc = -1
    avg_mcc = 0

    num_classes = 0
    
    accuracies = []
    f1_macro_scores = []
    f1_micro_scores = []
    mcc_scores = []

    session_id_for_df = session.get_trial_id()
    
    for i in range(5):
        accuracy, f1_macro, f1_micro, mcc, num_classes = evaluate_model_on_dataset_one_split(config, splits, i)
        accuracies.append(accuracy)
        f1_macro_scores.append(f1_macro)
        f1_micro_scores.append(f1_micro)
        mcc_scores.append(mcc)
        
        avg_accuracy += accuracy
        avg_f1_macro += f1_macro
        avg_f1_micro += f1_micro
        min_accuracy = min(min_accuracy, accuracy)
        max_accuracy = max(max_accuracy, accuracy)
        min_f1_macro = min(min_f1_macro, f1_macro)
        max_f1_macro = max(max_f1_macro, f1_macro)
        min_f1_micro = min(min_f1_micro, f1_micro)
        max_f1_micro = max(max_f1_micro, f1_micro)
        avg_mcc += mcc
        min_mcc = min(min_mcc, mcc)
        max_mcc = max(max_mcc, mcc)


        
        data_spike_exec_1_split_dict[splits_name + "_" + str(i+1) + "_" + session_id_for_df] = {
            "number of classes": num_classes,
            "accuracy": accuracy,
            "macro f1": f1_macro,
            "micro_f1": f1_micro,
            "mcc": mcc,
            "config": str(config)
        }
        
       
    temp_df = pd.DataFrame.from_dict(data_spike_exec_1_split_dict, orient='index')
    df_data_spike_1_split = pd.concat([df_data_spike_1_split, temp_df], axis=0)

        # df_data_spike_1_split = pd.concat([df_data_spike_1_split, pd.DataFrame.from_dict(data_spike_exec_1_split_dict)], axis=1)

        
    avg_accuracy /= 5
    avg_f1_macro /= 5
    avg_f1_micro /= 5
    avg_mcc /= 5
    
    data_spike_exec_full_split_dict[splits_name + "_" + session_id_for_df] = {
        "number of classes": num_classes,
        "min_accuracy": min_accuracy,
        "max_accuracy": max_accuracy,
        "mean_accuracy": np.mean(accuracies),
        "min_f1_macro": min_f1_macro,
        "max_f1_macro": max_f1_macro,
        "mean_f1_macro": np.mean(f1_macro_scores),
        "min_f1_micro": min_f1_micro,
        "max_f1_micro": max_f1_micro,
        "mean_f1_micro": np.mean(f1_micro_scores),
        "min_mcc": min_mcc,
        "max_mcc": max_mcc,
        "mean_mcc": np.mean(mcc_scores),
        "std_accuracy": np.std(accuracies),
        "std_f1_macro": np.std(f1_macro_scores),
        "std_f1_micro": np.std(f1_micro_scores),
        "std_mcc": np.std(mcc_scores),
        "config": str(config)
    }

    # print(f"Mean accuracy of the model {splits_name + '_' + session_id_for_df}: {avg_accuracy}")

    df_data_spike_full_split = pd.DataFrame.from_dict(data_spike_exec_full_split_dict, orient='index')

    # Load existing data from file if it exists and append new data
    full_split_path = os.path.join(helper.results_dir, f'output_full_{splits_name}.pkl')
    if os.path.exists(full_split_path):
        df_existing_full = pd.read_pickle(full_split_path)
        df_data_spike_full_split = pd.concat([df_existing_full, df_data_spike_full_split], axis=0)
    else:
        print(f"No existing full split data found at {full_split_path}, creating new file.")
    
    # Save the updated full split data to file
    df_data_spike_full_split.to_pickle(full_split_path)

    # Save the 1 split data using the full path
    split_path = os.path.join(helper.results_dir, f'output_{splits_name}.pkl')
    if os.path.exists(split_path):
        df_existing_1_spike = pd.read_pickle(split_path)
        df_data_spike_1_split = pd.concat([df_existing_1_spike, df_data_spike_1_split], axis=0)
    else:
        print(f"No existing 1 split data found at {split_path}, creating new file")

    # Save the updated 1 split data to file
    df_data_spike_1_split.to_pickle(split_path)

    time.sleep(5)
    
    session.report({
        "min_accuracy": min_accuracy,
        "max_accuracy": max_accuracy,
        "mean_accuracy": np.mean(accuracies),
        "min_f1_macro": min_f1_macro,
        "max_f1_macro": max_f1_macro,
        "mean_f1_macro": np.mean(f1_macro_scores),
        "min_f1_micro": min_f1_micro,
        "max_f1_micro": max_f1_micro,
        "mean_f1_micro": np.mean(f1_micro_scores)
    })

# %%
def generate_hidden_layers_config(min_layers=2, max_layers=5, min_nodes=30, max_nodes=90, step=5):
    possible_layers = []
    for num_layers in range(min_layers, max_layers + 1):
        layer_configurations = list(itertools.product(range(min_nodes, max_nodes + 1, step), repeat=num_layers))
        possible_layers.extend(layer_configurations)
    return possible_layers

def five_fold_cross_validation(splits, splits_name):

    global best_params_list_getting

    hidden_layers_options = generate_hidden_layers_config()

    config = {
        "activation": tune.choice(["relu", "tanh", "sigmoid"]),
        "learning_rate": tune.loguniform(1e-4, 1e-2),
        "batch_size": tune.choice([32, 64, 128]),
        "hidden_layers": tune.choice(hidden_layers_options),
        "epochs": tune.choice([10, 20, 30, 40, 50]),
        "dropout_rate": tune.uniform(0.2, 0.5)
    }
    
    scheduler = ASHAScheduler(
        metric="mean_accuracy",
        mode="max",
        max_t=10,
        grace_period=1,
        reduction_factor=2
    )
    
    search_alg = OptunaSearch(metric="mean_accuracy", mode="max")
    
    analysis = tune.run(
        tune.with_parameters(train_and_evaluate, splits=splits, splits_name=splits_name),
        resources_per_trial={"cpu": 10, "gpu": 0, "accelerator_type:RTX": 0},
        config=config,
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=32,
        verbose=1,
        storage_path=helper.ray_results_dir,
        trial_dirname_creator=custom_trial_dirname
    )

    best_config_data_ray_tune = analysis.get_best_config(metric="mean_accuracy", mode="max")
    print("Best hyperparameters found were: ", best_config_data_ray_tune)
    best_params_list_getting.append(best_config_data_ray_tune)
    
    return analysis

# %%
analysis = five_fold_cross_validation(helper.a2_splits, "A2")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-08-11 19:10:35</td></tr>
# <tr><td>Running for: </td><td>00:18:14.68        </td></tr>
# <tr><td>Memory:      </td><td>5.5/16.0 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=16<br>Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.9328487365870544<br>Logical resource usage: 10.0/10 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status    </th><th>loc            </th><th>activation  </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout_rate</th><th style="text-align: right;">  epochs</th><th>hidden_layers       </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  min_accuracy</th><th style="text-align: right;">  max_accuracy</th><th style="text-align: right;">  min_f1_macro</th></tr>
# </thead>
# <tbody>
# <tr><td>train_and_evaluate_3be12bdc</td><td>TERMINATED</td><td>127.0.0.1:46872</td><td>sigmoid     </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.417704</td><td style="text-align: right;">      10</td><td>(45, 75, 35, 85, 45)</td><td style="text-align: right;">    0.000467954</td><td style="text-align: right;">0.501869</td><td style="text-align: right;">     1</td><td style="text-align: right;">        18.1461 </td><td style="text-align: right;">      0.495327</td><td style="text-align: right;">      0.504673</td><td style="text-align: right;">      0.33125 </td></tr>
# <tr><td>train_and_evaluate_95079101</td><td>TERMINATED</td><td>127.0.0.1:46936</td><td>tanh        </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.237051</td><td style="text-align: right;">      40</td><td>(55, 90, 60, 35, 85)</td><td style="text-align: right;">    0.00333946 </td><td style="text-align: right;">0.938439</td><td style="text-align: right;">     1</td><td style="text-align: right;">        22.3422 </td><td style="text-align: right;">      0.925234</td><td style="text-align: right;">      0.953271</td><td style="text-align: right;">      0.925227</td></tr>
# <tr><td>train_and_evaluate_d49a173e</td><td>TERMINATED</td><td>127.0.0.1:47006</td><td>tanh        </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.43092 </td><td style="text-align: right;">      40</td><td>(45, 90, 45, 30, 80)</td><td style="text-align: right;">    0.000197976</td><td style="text-align: right;">0.938439</td><td style="text-align: right;">     1</td><td style="text-align: right;">        47.1356 </td><td style="text-align: right;">      0.915888</td><td style="text-align: right;">      0.971963</td><td style="text-align: right;">      0.915858</td></tr>
# <tr><td>train_and_evaluate_96fdd486</td><td>TERMINATED</td><td>127.0.0.1:47124</td><td>sigmoid     </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.479227</td><td style="text-align: right;">      30</td><td>(55, 65, 35, 55, 70)</td><td style="text-align: right;">    0.00362725 </td><td style="text-align: right;">0.561682</td><td style="text-align: right;">     1</td><td style="text-align: right;">        34.9202 </td><td style="text-align: right;">      0.495327</td><td style="text-align: right;">      0.803738</td><td style="text-align: right;">      0.33125 </td></tr>
# <tr><td>train_and_evaluate_0ea78f4e</td><td>TERMINATED</td><td>127.0.0.1:47213</td><td>relu        </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.245914</td><td style="text-align: right;">      30</td><td>(50, 75, 55, 40, 60)</td><td style="text-align: right;">    0.00137773 </td><td style="text-align: right;">0.945898</td><td style="text-align: right;">     1</td><td style="text-align: right;">        35.9655 </td><td style="text-align: right;">      0.915888</td><td style="text-align: right;">      0.981308</td><td style="text-align: right;">      0.915858</td></tr>
# <tr><td>train_and_evaluate_1337bc5b</td><td>TERMINATED</td><td>127.0.0.1:47328</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.396802</td><td style="text-align: right;">      20</td><td>(50, 80, 70, 45, 80)</td><td style="text-align: right;">    0.00135388 </td><td style="text-align: right;">0.927276</td><td style="text-align: right;">     1</td><td style="text-align: right;">        16.8517 </td><td style="text-align: right;">      0.906542</td><td style="text-align: right;">      0.953271</td><td style="text-align: right;">      0.906469</td></tr>
# <tr><td>train_and_evaluate_8c21c568</td><td>TERMINATED</td><td>127.0.0.1:47386</td><td>relu        </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.465666</td><td style="text-align: right;">      20</td><td>(75, 30, 45, 70, 30)</td><td style="text-align: right;">    0.00154578 </td><td style="text-align: right;">0.934735</td><td style="text-align: right;">     1</td><td style="text-align: right;">        26.027  </td><td style="text-align: right;">      0.906542</td><td style="text-align: right;">      0.962617</td><td style="text-align: right;">      0.906534</td></tr>
# <tr><td>train_and_evaluate_3ad116b9</td><td>TERMINATED</td><td>127.0.0.1:47457</td><td>tanh        </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.220941</td><td style="text-align: right;">      20</td><td>(60, 30, 90, 45, 85)</td><td style="text-align: right;">    0.00292242 </td><td style="text-align: right;">0.938474</td><td style="text-align: right;">     1</td><td style="text-align: right;">        12.6835 </td><td style="text-align: right;">      0.916667</td><td style="text-align: right;">      0.962617</td><td style="text-align: right;">      0.916315</td></tr>
# <tr><td>train_and_evaluate_ab859f64</td><td>TERMINATED</td><td>127.0.0.1:47497</td><td>relu        </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.369645</td><td style="text-align: right;">      10</td><td>(80, 45, 60, 85, 80)</td><td style="text-align: right;">    0.00871615 </td><td style="text-align: right;">0.768363</td><td style="text-align: right;">     1</td><td style="text-align: right;">         9.36811</td><td style="text-align: right;">      0.495327</td><td style="text-align: right;">      0.925926</td><td style="text-align: right;">      0.33125 </td></tr>
# <tr><td>train_and_evaluate_cf2179c3</td><td>TERMINATED</td><td>127.0.0.1:47537</td><td>sigmoid     </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.334026</td><td style="text-align: right;">      50</td><td>(30, 75, 35, 75, 75)</td><td style="text-align: right;">    0.00676706 </td><td style="text-align: right;">0.5     </td><td style="text-align: right;">     1</td><td style="text-align: right;">        66.3148 </td><td style="text-align: right;">      0.495327</td><td style="text-align: right;">      0.504673</td><td style="text-align: right;">      0.33125 </td></tr>
# <tr><td>train_and_evaluate_31291d74</td><td>TERMINATED</td><td>127.0.0.1:47655</td><td>sigmoid     </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.381483</td><td style="text-align: right;">      50</td><td>(60, 45, 60, 75, 75)</td><td style="text-align: right;">    0.000266064</td><td style="text-align: right;">0.651
# (train_and_evaluate pid=46872) No existing full split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_full_A2.pkl, creating new file.
# (train_and_evaluate pid=46872) No existing 1 split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_A2.pkl, creating new file
# 2024-08-11 18:52:44,147	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (45, 75, 35, 85, 45)}
# 2024-08-11 18:53:10,964	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (55, 90, 60, 35, 85)}
# 2024-08-11 18:54:02,808	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (45, 90, 45, 30, 80)}
# 2024-08-11 18:54:41,332	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (55, 65, 35, 55, 70)}
# 2024-08-11 18:55:21,439	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 75, 55, 40, 60)}
# 2024-08-11 18:55:42,354	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 80, 70, 45, 80)}
# 2024-08-11 18:56:12,158	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 30, 45, 70, 30)}
# 2024-08-11 18:56:28,808	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 30, 90, 45, 85)}
# 2024-08-11 18:56:41,565	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 45, 60, 85, 80)}
# 2024-08-11 18:57:51,559	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 75, 35, 75, 75)}
# 2024-08-11 18:58:38,137	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 45, 60, 75, 75)}
# 2024-08-11 18:59:01,550	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 40, 30, 35)}
# 2024-08-11 18:59:26,784	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 90, 90, 45, 45)}
# 2024-08-11 18:59:46,491	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (40, 45, 60, 90, 30)}
# 2024-08-11 19:00:03,393	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 30, 75, 50, 50)}
# 2024-08-11 19:00:18,447	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 75, 80, 50, 85)}
# 2024-08-11 19:00:47,626	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 50, 45, 85, 50)}
# 2024-08-11 19:01:26,950	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (70, 70, 80, 90, 55)}
# 2024-08-11 19:02:06,487	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 80, 40, 30, 50)}
# 2024-08-11 19:02:19,470	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 60, 60, 35, 55)}
# 2024-08-11 19:02:32,472	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 30, 50, 80, 85)}
# 2024-08-11 19:03:05,403	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 65, 60, 65, 80)}
# 2024-08-11 19:03:31,500	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 60, 35, 50, 45)}
# 2024-08-11 19:03:59,783	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 35, 80, 70, 65)}
# 2024-08-11 19:04:26,892	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 30, 90, 80, 75)}
# 2024-08-11 19:04:57,753	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (90, 70, 50, 35, 65)}
# 2024-08-11 19:05:45,941	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 60, 70, 70, 90)}
# 2024-08-11 19:06:34,686	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (55, 75, 65, 50, 65)}
# 2024-08-11 19:07:21,881	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 70, 65, 35, 30)}
# 2024-08-11 19:08:17,185	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 80, 60, 55, 55)}
# 2024-08-11 19:09:27,834	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 40, 60, 70, 60)}
# 2024-08-11 19:10:35,655	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 65, 45, 30, 80)}
# 2024-08-11 19:10:35,787	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/ray_results/train_and_evaluate_2024-08-11_18-52-18' in 0.1261s.
# 2024-08-11 19:10:35,797	INFO tune.py:1041 -- Total run time: 1098.91 seconds (1094.55 seconds for the tuning loop).
# Best hyperparameters found were:  {'activation': 'tanh', 'learning_rate': 0.0019262652782999904, 'batch_size': 128, 'hidden_layers': (30, 60, 70, 70, 90), 'epochs': 50, 'dropout_rate': 0.2953090215174134}

# %%
analysis = five_fold_cross_validation(helper.a3_splits, "A3")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-08-11 19:26:51</td></tr>
# <tr><td>Running for: </td><td>00:16:11.02        </td></tr>
# <tr><td>Memory:      </td><td>6.0/16.0 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=15<br>Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.8786749482401657<br>Logical resource usage: 10.0/10 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status    </th><th>loc            </th><th>activation  </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout_rate</th><th style="text-align: right;">  epochs</th><th>hidden_layers       </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  min_accuracy</th><th style="text-align: right;">  max_accuracy</th><th style="text-align: right;">  min_f1_macro</th></tr>
# </thead>
# <tbody>
# <tr><td>train_and_evaluate_548ded92</td><td>TERMINATED</td><td>127.0.0.1:49314</td><td>relu        </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.404952</td><td style="text-align: right;">      50</td><td>(35, 55, 80, 30, 65)</td><td style="text-align: right;">    0.000275817</td><td style="text-align: right;">0.895901</td><td style="text-align: right;">     1</td><td style="text-align: right;">        35.0354 </td><td style="text-align: right;">      0.855072</td><td style="text-align: right;">      0.942029</td><td style="text-align: right;">      0.855042</td></tr>
# <tr><td>train_and_evaluate_96a6e365</td><td>TERMINATED</td><td>127.0.0.1:49378</td><td>relu        </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.28108 </td><td style="text-align: right;">      50</td><td>(40, 80, 35, 65, 50)</td><td style="text-align: right;">    0.000390557</td><td style="text-align: right;">0.892961</td><td style="text-align: right;">     1</td><td style="text-align: right;">        17.0419 </td><td style="text-align: right;">      0.84058 </td><td style="text-align: right;">      0.928571</td><td style="text-align: right;">      0.840042</td></tr>
# <tr><td>train_and_evaluate_56ff8777</td><td>TERMINATED</td><td>127.0.0.1:49412</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.241767</td><td style="text-align: right;">      30</td><td>(40, 55, 35, 55, 30)</td><td style="text-align: right;">    0.00582972 </td><td style="text-align: right;">0.6494  </td><td style="text-align: right;">     1</td><td style="text-align: right;">        15.9005 </td><td style="text-align: right;">      0.492754</td><td style="text-align: right;">      0.957143</td><td style="text-align: right;">      0.330097</td></tr>
# <tr><td>train_and_evaluate_139beee9</td><td>TERMINATED</td><td>127.0.0.1:49447</td><td>sigmoid     </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.493103</td><td style="text-align: right;">      40</td><td>(30, 90, 65, 70, 55)</td><td style="text-align: right;">    0.00103917 </td><td style="text-align: right;">0.63913 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        15.2309 </td><td style="text-align: right;">      0.492754</td><td style="text-align: right;">      0.869565</td><td style="text-align: right;">      0.330097</td></tr>
# <tr><td>train_and_evaluate_32702152</td><td>TERMINATED</td><td>127.0.0.1:49527</td><td>relu        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.248855</td><td style="text-align: right;">      50</td><td>(90, 90, 70, 55, 85)</td><td style="text-align: right;">    0.000202708</td><td style="text-align: right;">0.904596</td><td style="text-align: right;">     1</td><td style="text-align: right;">        24.0063 </td><td style="text-align: right;">      0.869565</td><td style="text-align: right;">      0.942029</td><td style="text-align: right;">      0.869456</td></tr>
# <tr><td>train_and_evaluate_66c451c4</td><td>TERMINATED</td><td>127.0.0.1:49604</td><td>relu        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.21899 </td><td style="text-align: right;">      20</td><td>(55, 55, 75, 55, 50)</td><td style="text-align: right;">    0.000778105</td><td style="text-align: right;">0.875942</td><td style="text-align: right;">     1</td><td style="text-align: right;">        13.1716 </td><td style="text-align: right;">      0.8     </td><td style="text-align: right;">      0.971014</td><td style="text-align: right;">      0.797353</td></tr>
# <tr><td>train_and_evaluate_3dd87b5b</td><td>TERMINATED</td><td>127.0.0.1:49657</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.458046</td><td style="text-align: right;">      10</td><td>(60, 85, 75, 45, 65)</td><td style="text-align: right;">    0.00126628 </td><td style="text-align: right;">0.835114</td><td style="text-align: right;">     1</td><td style="text-align: right;">        10.6854 </td><td style="text-align: right;">      0.768116</td><td style="text-align: right;">      0.885714</td><td style="text-align: right;">      0.764103</td></tr>
# <tr><td>train_and_evaluate_c7035c45</td><td>TERMINATED</td><td>127.0.0.1:49730</td><td>sigmoid     </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.33216 </td><td style="text-align: right;">      20</td><td>(50, 80, 40, 55, 45)</td><td style="text-align: right;">    0.00306002 </td><td style="text-align: right;">0.52029 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        19.8784 </td><td style="text-align: right;">      0.492754</td><td style="text-align: right;">      0.565217</td><td style="text-align: right;">      0.330097</td></tr>
# <tr><td>train_and_evaluate_fb3641d3</td><td>TERMINATED</td><td>127.0.0.1:49846</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.216682</td><td style="text-align: right;">      10</td><td>(50, 75, 80, 40, 40)</td><td style="text-align: right;">    0.000344783</td><td style="text-align: right;">0.734451</td><td style="text-align: right;">     1</td><td style="text-align: right;">        10.0677 </td><td style="text-align: right;">      0.614286</td><td style="text-align: right;">      0.913043</td><td style="text-align: right;">      0.557895</td></tr>
# <tr><td>train_and_evaluate_1069c9ef</td><td>TERMINATED</td><td>127.0.0.1:49877</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.265502</td><td style="text-align: right;">      20</td><td>(40, 90, 80, 45, 80)</td><td style="text-align: right;">    0.000168806</td><td style="text-align: right;">0.791884</td><td style="text-align: right;">     1</td><td style="text-align: right;">        13.2597 </td><td style="text-align: right;">      0.666667</td><td style="text-align: right;">      0.855072</td><td style="text-align: right;">      0.665543</td></tr>
# <tr><td>train_and_evaluate_93a5896b</td><td>TERMINATED</td><td>127.0.0.1:49904</td><td>sigmoid     </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.317876</td><td style="text-align: right;">      10</td><td>(65, 65, 55, 90, 70)</td><td style="text-align: right;">    0.00438857 </td><td style="text-align: right;">0.502
# (train_and_evaluate pid=49314) No existing full split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_full_A3.pkl, creating new file.
# (train_and_evaluate pid=49314) No existing 1 split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_A3.pkl, creating new file
# 2024-08-11 19:11:20,043	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (35, 55, 80, 30, 65)}
# 2024-08-11 19:11:40,286	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (40, 80, 35, 65, 50)}
# 2024-08-11 19:12:00,267	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (40, 55, 35, 55, 30)}
# 2024-08-11 19:12:19,289	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 90, 65, 70, 55)}
# 2024-08-11 19:12:47,597	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (90, 90, 70, 55, 85)}
# 2024-08-11 19:13:04,964	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (55, 55, 75, 55, 50)}
# 2024-08-11 19:13:19,110	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 85, 75, 45, 65)}
# 2024-08-11 19:13:42,500	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 80, 40, 55, 45)}
# 2024-08-11 19:13:56,874	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 75, 80, 40, 40)}
# 2024-08-11 19:14:13,868	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (40, 90, 80, 45, 80)}
# 2024-08-11 19:14:26,002	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 65, 55, 90, 70)}
# 2024-08-11 19:15:07,221	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 30, 80, 80, 55)}
# 2024-08-11 19:15:50,976	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 90, 35, 50, 65)}
# 2024-08-11 19:16:32,457	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 90, 30, 90, 40)}
# 2024-08-11 19:17:13,704	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (45, 75, 75, 50, 35)}
# 2024-08-11 19:17:54,425	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (70, 75, 75, 55, 55)}
# 2024-08-11 19:18:13,616	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 40, 75, 55, 90)}
# 2024-08-11 19:18:36,979	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 50, 75, 65, 90)}
# 2024-08-11 19:19:10,647	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (70, 70, 50, 60, 35)}
# 2024-08-11 19:19:50,982	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 40, 30, 65, 55)}
# 2024-08-11 19:20:12,928	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 60, 75, 75, 60)}
# 2024-08-11 19:20:36,348	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 70, 35, 70, 55)}
# 2024-08-11 19:21:18,392	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 45, 55, 75, 90)}
# 2024-08-11 19:22:02,805	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (55, 55, 50, 75, 90)}
# 2024-08-11 19:22:48,959	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 50, 40, 35, 65)}
# 2024-08-11 19:23:30,992	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (45, 75, 90, 60, 45)}
# 2024-08-11 19:23:59,463	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (35, 55, 55, 50, 35)}
# 2024-08-11 19:24:19,717	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 30, 60, 90, 50)}
# 2024-08-11 19:24:46,736	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 55, 90, 75, 55)}
# 2024-08-11 19:25:27,058	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 35, 90, 80, 30)}
# 2024-08-11 19:26:08,832	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (35, 30, 60, 90, 85)}
# 2024-08-11 19:26:51,003	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 90, 45, 85, 60)}
# 2024-08-11 19:26:51,134	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/ray_results/train_and_evaluate_2024-08-11_19-10-37' in 0.1285s.
# 2024-08-11 19:26:51,146	INFO tune.py:1041 -- Total run time: 975.09 seconds (970.89 seconds for the tuning loop).
# Best hyperparameters found were:  {'activation': 'relu', 'learning_rate': 0.00017299494004745534, 'batch_size': 32, 'hidden_layers': (75, 35, 90, 80, 30), 'epochs': 50, 'dropout_rate': 0.4633289995400754}

# %%
analysis = five_fold_cross_validation(helper.a4_splits, "A4")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-08-11 19:39:04</td></tr>
# <tr><td>Running for: </td><td>00:12:10.66        </td></tr>
# <tr><td>Memory:      </td><td>13.0/16.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=7<br>Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.34942586636700634<br>Logical resource usage: 10.0/10 CPUs, 0/0 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 22<br><table>
# <thead>
# <tr><th>Trial name                 </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                      </th></tr>
# </thead>
# <tbody>
# <tr><td>train_and_evaluate_d7aa7cfd</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_d7aa7cfd/error.txt</td></tr>
# <tr><td>train_and_evaluate_2bb87ded</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_2bb87ded/error.txt</td></tr>
# <tr><td>train_and_evaluate_36e7005f</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_36e7005f/error.txt</td></tr>
# <tr><td>train_and_evaluate_e6fe4736</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_e6fe4736/error.txt</td></tr>
# <tr><td>train_and_evaluate_a0c119f1</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_a0c119f1/error.txt</td></tr>
# <tr><td>train_and_evaluate_1aed5099</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_1aed5099/error.txt</td></tr>
# <tr><td>train_and_evaluate_a293e423</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_a293e423/error.txt</td></tr>
# <tr><td>train_and_evaluate_07e69b05</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_07e69b05/error.txt</td></tr>
# <tr><td>train_and_evaluate_429938f3</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_429938f3/error.txt</td></tr>
# <tr><td>train_and_evaluate_987ab45d</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_987ab45d/error.txt</td></tr>
# <tr><td>train_and_evaluate_96a04572</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_96a04572/error.txt</td></tr>
# <tr><td>train_and_evaluate_27e1d6a9</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_27e1d6a9/error.txt</td></tr>
# <tr><td>train_and_evaluate_d1c4a15c</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_d1c4a15c/error.txt</td></tr>
# <tr><td>train_and_evaluate_83da32ae</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_83da32ae/error.txt</td></tr>
# <tr><td>train_and_evaluate_c85bbf26</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_c85bbf26/error.txt</td></tr>
# <tr><td>train_and_evaluate_76215a81</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_76215a81/error.txt</td></tr>
# <tr><td>train_and_evaluate_d891c68f</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_d891c68f/error.txt</td></tr>
# <tr><td>train_and_evaluate_d0e63d7a</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_d0e63d7a/error.txt</td></tr>
# <tr><td>train_and_evaluate_60df87d5</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_60df87d5/error.txt</td></tr>
# <tr><td>train_and_evaluate_0eb97715</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_0eb97715/error.txt</td></tr>
# <tr><td>train_and_evaluate_0f8d0aa6</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_0f8d0aa6/error.txt</td></tr>
# <tr><td>train_and_evaluate_c47ca1ae</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_19-26-53/train_and_evaluate_2024-08-11_19-26-53/driver_artifacts/trial_c47ca1ae/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status    </th><th>loc            </th><th>activation  </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout_rate</th><th style="text-align: right;">  epochs</th><th>hidden_layers       </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  min_accuracy</th><th style="text-align: right;">  max_accuracy</th><th style="text-align: right;">  min_f1_macro</th></tr>
# </thead>
# 2024-08-11 19:27:09,053	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_d7aa7cfd
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51437, ip=127.0.0.1, actor_id=d0caf907107659fc2ed939c501000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 56.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 277.50 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:27:31,404	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_2bb87ded
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51483, ip=127.0.0.1, actor_id=d3040c76be9c0209e1e110c501000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.10 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:27:43,879	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_36e7005f
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51534, ip=127.0.0.1, actor_id=6192c7be60c4356fe32a22c901000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 96.00 MB, other allocations: 18.06 GB, max allowed: 18.13 GB). Tried to allocate 128.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# (train_and_evaluate pid=51560) No existing full split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_full_A4.pkl, creating new file.
# (train_and_evaluate pid=51560) No existing 1 split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_A4.pkl, creating new file
# 2024-08-11 19:28:33,475	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (55, 75, 50, 50, 70)}
# 2024-08-11 19:28:53,512	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_e6fe4736
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51639, ip=127.0.0.1, actor_id=de6ab494a3bae0e70b3fc7db01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.10 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:29:04,998	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_a0c119f1
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51682, ip=127.0.0.1, actor_id=423912af9db3cdb253562f4701000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 96.00 MB, other allocations: 18.06 GB, max allowed: 18.13 GB). Tried to allocate 128.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:29:21,514	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_1aed5099
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51707, ip=127.0.0.1, actor_id=5012bbc23989f346817e487c01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 56.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 277.50 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:29:32,524	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_a293e423
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51742, ip=127.0.0.1, actor_id=0c3151f632e62eac9d39b33201000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 96.00 MB, other allocations: 18.06 GB, max allowed: 18.13 GB). Tried to allocate 128.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:29:47,818	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_07e69b05
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51772, ip=127.0.0.1, actor_id=09b403cf3df49af85a0e776e01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 56.00 MB, other allocations: 18.10 GB, max allowed: 18.13 GB). Tried to allocate 277.50 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:30:01,500	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_429938f3
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=51808, ip=127.0.0.1, actor_id=1e28c052bf820a0d7a97277e01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 96.00 MB, other allocations: 18.06 GB, max allowed: 18.13 GB). Tried to allocate 128.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:30:30,618	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 30, 75, 70, 75)}
# 2024-08-11 19:31:01,473	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 75, 85, 65, 65)}
# 2024-08-11 19:31:14,644	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_987ab45d
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=52092, ip=127.0.0.1, actor_id=671500dc8a90da9c713cec4b01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 56.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 277.50 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:31:35,795	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_96a04572
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=52138, ip=127.0.0.1, actor_id=6df882ea0862ac6a2ad87d3101000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
# ...
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 96.00 MB, other allocations: 18.06 GB, max allowed: 18.13 GB). Tried to allocate 128.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:38:09,670	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 70, 90, 45, 40)}
# 2024-08-11 19:38:24,818	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_0eb97715
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=53013, ip=127.0.0.1, actor_id=7221bae9e3a4a1a9d96a0b7501000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 56.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 277.50 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:38:44,078	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_0f8d0aa6
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=53064, ip=127.0.0.1, actor_id=7ada4048557b3f38c35a15b101000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.10 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:39:03,906	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_c47ca1ae
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=53106, ip=127.0.0.1, actor_id=7a1793a4dd9a473f47441df101000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.10 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 19:39:04,759	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/ray_results/train_and_evaluate_2024-08-11_19-26-53' in 0.1370s.
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 analysis = five_fold_cross_validation(helper.a4_splits, "A4")
#
# Cell In[8], line 33, in five_fold_cross_validation(splits, splits_name)
#      23 scheduler = ASHAScheduler(
#      24     metric="mean_accuracy",
#      25     mode="max",
#    (...)
#      28     reduction_factor=2
#      29 )
#      31 search_alg = OptunaSearch(metric="mean_accuracy", mode="max")
# ---> 33 analysis = tune.run(
#      34     tune.with_parameters(train_and_evaluate, splits=splits, splits_name=splits_name),
#      35     resources_per_trial={"cpu": 10, "gpu": 0, "accelerator_type:RTX": 0},
#      36     config=config,
#      37     scheduler=scheduler,
#      38     search_alg=search_alg,
#      39     num_samples=32,
#      40     verbose=1,
#      41     storage_path=helper.ray_results_dir,
#      42     trial_dirname_creator=custom_trial_dirname
#      43 )
#      45 best_config_data_ray_tune = analysis.get_best_config(metric="mean_accuracy", mode="max")
#      46 print("Best hyperparameters found were: ", best_config_data_ray_tune)
#
# File ~/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/tune.py:1035, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#    1033 if incomplete_trials:
#    1034     if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1035         raise TuneError("Trials did not complete", incomplete_trials)
#    1036     else:
#    1037         logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [train_and_evaluate_d7aa7cfd, train_and_evaluate_2bb87ded, train_and_evaluate_36e7005f, train_and_evaluate_e6fe4736, train_and_evaluate_a0c119f1, train_and_evaluate_1aed5099, train_and_evaluate_a293e423, train_and_evaluate_07e69b05, train_and_evaluate_429938f3, train_and_evaluate_987ab45d, train_and_evaluate_96a04572, train_and_evaluate_27e1d6a9, train_and_evaluate_d1c4a15c, train_and_evaluate_83da32ae, train_and_evaluate_c85bbf26, train_and_evaluate_76215a81, train_and_evaluate_d891c68f, train_and_evaluate_d0e63d7a, train_and_evaluate_60df87d5, train_and_evaluate_0eb97715, train_and_evaluate_0f8d0aa6, train_and_evaluate_c47ca1ae])

# %%
analysis = five_fold_cross_validation(helper.a12_splits, "A12")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-08-11 20:15:44</td></tr>
# <tr><td>Running for: </td><td>00:10:39.63        </td></tr>
# <tr><td>Memory:      </td><td>12.2/16.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=1<br>Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.23139735711129855<br>Logical resource usage: 10.0/10 CPUs, 0/0 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 27<br><table>
# <thead>
# <tr><th>Trial name                 </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                      </th></tr>
# </thead>
# <tbody>
# <tr><td>train_and_evaluate_9adf5100</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_9adf5100/error.txt</td></tr>
# <tr><td>train_and_evaluate_d2a64b8b</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_d2a64b8b/error.txt</td></tr>
# <tr><td>train_and_evaluate_28d97874</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_28d97874/error.txt</td></tr>
# <tr><td>train_and_evaluate_09d484d2</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_09d484d2/error.txt</td></tr>
# <tr><td>train_and_evaluate_06538bc3</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_06538bc3/error.txt</td></tr>
# <tr><td>train_and_evaluate_7cf7117d</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_7cf7117d/error.txt</td></tr>
# <tr><td>train_and_evaluate_2ff1e38d</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_2ff1e38d/error.txt</td></tr>
# <tr><td>train_and_evaluate_75c4cf38</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_75c4cf38/error.txt</td></tr>
# <tr><td>train_and_evaluate_a1c4a906</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_a1c4a906/error.txt</td></tr>
# <tr><td>train_and_evaluate_d204cd2c</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_d204cd2c/error.txt</td></tr>
# <tr><td>train_and_evaluate_3a6c501b</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_3a6c501b/error.txt</td></tr>
# <tr><td>train_and_evaluate_ec745a39</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_ec745a39/error.txt</td></tr>
# <tr><td>train_and_evaluate_cb617f5c</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_cb617f5c/error.txt</td></tr>
# <tr><td>train_and_evaluate_636bdc69</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_636bdc69/error.txt</td></tr>
# <tr><td>train_and_evaluate_b0283106</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_b0283106/error.txt</td></tr>
# <tr><td>train_and_evaluate_1cf6e529</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_1cf6e529/error.txt</td></tr>
# <tr><td>train_and_evaluate_7dc1254f</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_7dc1254f/error.txt</td></tr>
# <tr><td>train_and_evaluate_75a21916</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_75a21916/error.txt</td></tr>
# <tr><td>train_and_evaluate_669c3e5a</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_669c3e5a/error.txt</td></tr>
# <tr><td>train_and_evaluate_da996678</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_da996678/error.txt</td></tr>
# <tr><td>train_and_evaluate_8a8a0ed2</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_8a8a0ed2/error.txt</td></tr>
# <tr><td>train_and_evaluate_012d22d7</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_012d22d7/error.txt</td></tr>
# <tr><td>train_and_evaluate_920e6970</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_920e6970/error.txt</td></tr>
# <tr><td>train_and_evaluate_fdc7bda1</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_fdc7bda1/error.txt</td></tr>
# <tr><td>train_and_evaluate_e646c9ae</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_e646c9ae/error.txt</td></tr>
# <tr><td>train_and_evaluate_b59f2895</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2024-08-11_18-52-09_864798_46794/artifacts/2024-08-11_20-05-03/train_and_evaluate_2024-08-11_20-05-03/driver_artifacts/trial_b59f2895/error.txt</td></tr>
# <tr><td>train_and_evaluate_3fe10aff</td><td style="text-align: right
# (train_and_evaluate pid=55808) No existing full split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_full_A12.pkl, creating new file.
# (train_and_evaluate pid=55808) No existing 1 split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_A12.pkl, creating new file
# 2024-08-11 20:05:31,705	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 55, 30, 85, 75)}
# 2024-08-11 20:05:51,961	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_9adf5100
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=55875, ip=127.0.0.1, actor_id=3e00f052dd2775ba9ff1289201000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:06:12,319	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_d2a64b8b
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=55921, ip=127.0.0.1, actor_id=58a24e2422226ca7c73234f601000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:06:32,783	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_28d97874
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=55968, ip=127.0.0.1, actor_id=4a132699e14e364e498791ea01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 56.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:06:47,808	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_09d484d2
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=56010, ip=127.0.0.1, actor_id=f420f83dc4c24d66a1c6b63f01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 56.00 MB, other allocations: 18.10 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:07:02,575	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_06538bc3
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=56048, ip=127.0.0.1, actor_id=b237466f5e8c8f87eec3c95e01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 26, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/_tensor.py", line 521, in backward
#     torch.autograd.backward(
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/autograd/__init__.py", line 289, in backward
#     _engine_run_backward(
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/autograd/graph.py", line 768, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.07 GB, max allowed: 18.13 GB). Tried to allocate 64.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:07:18,073	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_7cf7117d
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=56083, ip=127.0.0.1, actor_id=e899c56d79122048cd8baf7201000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 26, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/_tensor.py", line 521, in backward
#     torch.autograd.backward(
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/autograd/__init__.py", line 289, in backward
#     _engine_run_backward(
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/autograd/graph.py", line 768, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.07 GB, max allowed: 18.13 GB). Tried to allocate 64.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:07:33,206	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_2ff1e38d
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=56113, ip=127.0.0.1, actor_id=0a69bb95329424c7f699f88801000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 26, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/_tensor.py", line 521, in backward
#     torch.autograd.backward(
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/autograd/__init__.py", line 289, in backward
#     _engine_run_backward(
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/autograd/graph.py", line 768, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.07 GB, max allowed: 18.13 GB). Tried to allocate 64.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:08:21,267	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 45, 30, 45, 80)}
# 2024-08-11 20:09:32,780	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (90, 35, 85, 80, 85)}
# 2024-08-11 20:09:43,677	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_75c4cf38
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=56482, ip=127.0.0.1, actor_id=e382fe84ed6b2d0900807cc501000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 96.00 MB, other allocations: 18.06 GB, max allowed: 18.13 GB). Tried to allocate 128.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:09:56,247	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_a1c4a906
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=56531, ip=127.0.0.1, actor_id=0b73fc4730467ccafaf8537601000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 96.00 MB, other allocations: 18.06 GB, max allowed: 18.13 GB). Tried to allocate 128.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:10:11,223	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_d204cd2c
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=56559, ip=127.0.0.1, actor_id=12176a4643ccef7bb5c076da01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 26, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/_tensor.py", line 521, in backward
#     torch.autograd.backward(
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/autograd/__init__.py", line 289, in backward
#     _engine_run_backward(
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/autograd/graph.py", line 768, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.07 GB, max allowed: 18.13 GB). Tried to allocate 512.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:10:25,669	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_3a6c501b
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=56593, ip=127.0.0.1, actor_id=dce3b797d8e4bf1dfa0eab3201000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# ...
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:15:11,315	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_e646c9ae
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=57438, ip=127.0.0.1, actor_id=4c3893cc4a94385ba0f225f701000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 56.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:15:31,682	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_b59f2895
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=57501, ip=127.0.0.1, actor_id=0ec997b5218a00dc312f810901000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 64.00 MB, other allocations: 18.09 GB, max allowed: 18.13 GB). Tried to allocate 480.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:15:43,140	ERROR tune_controller.py:1331 -- Trial task failed for trial train_and_evaluate_3fe10aff
# Traceback (most recent call last):
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 2659, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/_private/worker.py", line 871, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=57561, ip=127.0.0.1, actor_id=ff96fc21d273ad823b7c47ec01000000, repr=train_and_evaluate)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/907211802.py", line 31, in train_and_evaluate
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/547545792.py", line 30, in evaluate_model_on_dataset_one_split
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/1965437044.py", line 24, in train
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/var/folders/1r/h80d31y92rn7dxwn7_1yfhsh0000gn/T/ipykernel_46794/3784337601.py", line 30, in forward
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/bhanuprasanna/anaconda3/envs/uni/lib/python3.10/site-packages/torch/nn/modules/rnn.py", line 917, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# RuntimeError: MPS backend out of memory (MPS allocated: 96.00 MB, other allocations: 18.06 GB, max allowed: 18.13 GB). Tried to allocate 128.00 KB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
# 2024-08-11 20:15:44,073	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/ray_results/train_and_evaluate_2024-08-11_20-05-03' in 0.1663s.
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 analysis = five_fold_cross_validation(helper.a12_splits, "A12")
#
# Cell In[8], line 33, in five_fold_cross_validation(splits, splits_name)
#      23 scheduler = ASHAScheduler(
#      24     metric="mean_accuracy",
#      25     mode="max",
#    (...)
#      28     reduction_factor=2
#      29 )
#      31 search_alg = OptunaSearch(metric="mean_accuracy", mode="max")
# ---> 33 analysis = tune.run(
#      34     tune.with_parameters(train_and_evaluate, splits=splits, splits_name=splits_name),
#      35     resources_per_trial={"cpu": 10, "gpu": 0, "accelerator_type:RTX": 0},
#      36     config=config,
#      37     scheduler=scheduler,
#      38     search_alg=search_alg,
#      39     num_samples=32,
#      40     verbose=1,
#      41     storage_path=helper.ray_results_dir,
#      42     trial_dirname_creator=custom_trial_dirname
#      43 )
#      45 best_config_data_ray_tune = analysis.get_best_config(metric="mean_accuracy", mode="max")
#      46 print("Best hyperparameters found were: ", best_config_data_ray_tune)
#
# File ~/anaconda3/envs/uni/lib/python3.10/site-packages/ray/tune/tune.py:1035, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#    1033 if incomplete_trials:
#    1034     if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1035         raise TuneError("Trials did not complete", incomplete_trials)
#    1036     else:
#    1037         logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [train_and_evaluate_9adf5100, train_and_evaluate_d2a64b8b, train_and_evaluate_28d97874, train_and_evaluate_09d484d2, train_and_evaluate_06538bc3, train_and_evaluate_7cf7117d, train_and_evaluate_2ff1e38d, train_and_evaluate_75c4cf38, train_and_evaluate_a1c4a906, train_and_evaluate_d204cd2c, train_and_evaluate_3a6c501b, train_and_evaluate_ec745a39, train_and_evaluate_cb617f5c, train_and_evaluate_636bdc69, train_and_evaluate_b0283106, train_and_evaluate_1cf6e529, train_and_evaluate_7dc1254f, train_and_evaluate_75a21916, train_and_evaluate_669c3e5a, train_and_evaluate_da996678, train_and_evaluate_8a8a0ed2, train_and_evaluate_012d22d7, train_and_evaluate_920e6970, train_and_evaluate_fdc7bda1, train_and_evaluate_e646c9ae, train_and_evaluate_b59f2895, train_and_evaluate_3fe10aff])

# %%
analysis = five_fold_cross_validation(helper.a21_splits, "A21")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-08-11 20:36:13</td></tr>
# <tr><td>Running for: </td><td>00:15:13.92        </td></tr>
# <tr><td>Memory:      </td><td>7.2/16.0 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=9<br>Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: 0.5894159928122193<br>Logical resource usage: 10.0/10 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status    </th><th>loc            </th><th>activation  </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout_rate</th><th style="text-align: right;">  epochs</th><th>hidden_layers       </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">     acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  min_accuracy</th><th style="text-align: right;">  max_accuracy</th><th style="text-align: right;">  min_f1_macro</th></tr>
# </thead>
# <tbody>
# <tr><td>train_and_evaluate_0b8fe88b</td><td>TERMINATED</td><td>127.0.0.1:58137</td><td>tanh        </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.37059 </td><td style="text-align: right;">      20</td><td>(80, 40, 45, 80, 30)</td><td style="text-align: right;">    0.00117455 </td><td style="text-align: right;">0.621797</td><td style="text-align: right;">     1</td><td style="text-align: right;">        25.2422 </td><td style="text-align: right;">      0.552381</td><td style="text-align: right;">      0.72381 </td><td style="text-align: right;">      0.355828</td></tr>
# <tr><td>train_and_evaluate_979dde3a</td><td>TERMINATED</td><td>127.0.0.1:58225</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.262826</td><td style="text-align: right;">      30</td><td>(50, 90, 50, 80, 40)</td><td style="text-align: right;">    0.0035575  </td><td style="text-align: right;">0.581797</td><td style="text-align: right;">     1</td><td style="text-align: right;">        21.2873 </td><td style="text-align: right;">      0.504762</td><td style="text-align: right;">      0.657143</td><td style="text-align: right;">      0.335443</td></tr>
# <tr><td>train_and_evaluate_f21b1399</td><td>TERMINATED</td><td>127.0.0.1:58286</td><td>sigmoid     </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.375458</td><td style="text-align: right;">      30</td><td>(40, 45, 50, 75, 90)</td><td style="text-align: right;">    0.00393669 </td><td style="text-align: right;">0.585606</td><td style="text-align: right;">     1</td><td style="text-align: right;">        34.5227 </td><td style="text-align: right;">      0.504762</td><td style="text-align: right;">      0.733333</td><td style="text-align: right;">      0.335443</td></tr>
# <tr><td>train_and_evaluate_3619d8a3</td><td>TERMINATED</td><td>127.0.0.1:58345</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.305895</td><td style="text-align: right;">      50</td><td>(55, 40, 90, 75, 90)</td><td style="text-align: right;">    0.00037305 </td><td style="text-align: right;">0.682426</td><td style="text-align: right;">     1</td><td style="text-align: right;">        46.7724 </td><td style="text-align: right;">      0.571429</td><td style="text-align: right;">      0.761905</td><td style="text-align: right;">      0.567506</td></tr>
# <tr><td>train_and_evaluate_075e65a1</td><td>TERMINATED</td><td>127.0.0.1:58455</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.405059</td><td style="text-align: right;">      30</td><td>(30, 75, 35, 35, 50)</td><td style="text-align: right;">    0.0013519  </td><td style="text-align: right;">0.689991</td><td style="text-align: right;">     1</td><td style="text-align: right;">        21.2096 </td><td style="text-align: right;">      0.580952</td><td style="text-align: right;">      0.771429</td><td style="text-align: right;">      0.4225  </td></tr>
# <tr><td>train_and_evaluate_c8221992</td><td>TERMINATED</td><td>127.0.0.1:58538</td><td>relu        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.34548 </td><td style="text-align: right;">      40</td><td>(80, 75, 90, 45, 30)</td><td style="text-align: right;">    0.00948457 </td><td style="text-align: right;">0.585606</td><td style="text-align: right;">     1</td><td style="text-align: right;">        30.4426 </td><td style="text-align: right;">      0.504762</td><td style="text-align: right;">      0.733333</td><td style="text-align: right;">      0.335443</td></tr>
# <tr><td>train_and_evaluate_bf8ab33b</td><td>TERMINATED</td><td>127.0.0.1:58638</td><td>relu        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.302926</td><td style="text-align: right;">      40</td><td>(80, 50, 90, 80)    </td><td style="text-align: right;">    0.000615584</td><td style="text-align: right;">0.693872</td><td style="text-align: right;">     1</td><td style="text-align: right;">        28.3753 </td><td style="text-align: right;">      0.638095</td><td style="text-align: right;">      0.752381</td><td style="text-align: right;">      0.610942</td></tr>
# <tr><td>train_and_evaluate_379189f2</td><td>TERMINATED</td><td>127.0.0.1:58695</td><td>tanh        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.49291 </td><td style="text-align: right;">      30</td><td>(90, 80, 60, 55, 60)</td><td style="text-align: right;">    0.00210974 </td><td style="text-align: right;">0.591321</td><td style="text-align: right;">     1</td><td style="text-align: right;">        20.7074 </td><td style="text-align: right;">      0.504762</td><td style="text-align: right;">      0.742857</td><td style="text-align: right;">      0.335443</td></tr>
# <tr><td>train_and_evaluate_6eeed24c</td><td>TERMINATED</td><td>127.0.0.1:58740</td><td>tanh        </td><td style="text-align: right;">         128</td><td style="text-align: right;">      0.209963</td><td style="text-align: right;">      10</td><td>(45, 75, 85, 85, 55)</td><td style="text-align: right;">    0.00185253 </td><td style="text-align: right;">0.568464</td><td style="text-align: right;">     1</td><td style="text-align: right;">         9.19395</td><td style="text-align: right;">      0.504762</td><td style="text-align: right;">      0.619048</td><td style="text-align: right;">      0.335443</td></tr>
# <tr><td>train_and_evaluate_23047baf</td><td>TERMINATED</td><td>127.0.0.1:58761</td><td>tanh        </td><td style="text-align: right;">          32</td><td style="text-align: right;">      0.312911</td><td style="text-align: right;">      30</td><td>(85, 55, 35, 85, 75)</td><td style="text-align: right;">    0.00407219 </td><td style="text-align: right;">0.585606</td><td style="text-align: right;">     1</td><td style="text-align: right;">        34.4494 </td><td style="text-align: right;">      0.504762</td><td style="text-align: right;">      0.733333</td><td style="text-align: right;">      0.335443</td></tr>
# <tr><td>train_and_evaluate_b5e50f52</td><td>TERMINATED</td><td>127.0.0.1:58830</td><td>relu        </td><td style="text-align: right;">          64</td><td style="text-align: right;">      0.499821</td><td style="text-align: right;">      50</td><td>(60, 45, 35, 40, 65)</td><td style="text-align: right;">    0.00402713 </td><td style="text-align: right;">0.5856
# (train_and_evaluate pid=58137) No existing full split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_full_A21.pkl, creating new file.
# (train_and_evaluate pid=58137) No existing 1 split data found at /Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/results/output_A21.pkl, creating new file
# 2024-08-11 20:21:30,693	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 40, 45, 80, 30)}
# 2024-08-11 20:21:56,191	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 90, 50, 80, 40)}
# 2024-08-11 20:22:34,397	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (40, 45, 50, 75, 90)}
# 2024-08-11 20:23:24,664	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (55, 40, 90, 75, 90)}
# 2024-08-11 20:23:50,466	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 75, 35, 35, 50)}
# 2024-08-11 20:24:24,643	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 75, 90, 45, 30)}
# 2024-08-11 20:24:56,696	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 50, 90, 80)}
# 2024-08-11 20:25:21,187	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (90, 80, 60, 55, 60)}
# 2024-08-11 20:25:34,366	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (45, 75, 85, 85, 55)}
# 2024-08-11 20:26:12,375	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 55, 35, 85, 75)}
# 2024-08-11 20:27:04,158	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 45, 35, 40, 65)}
# 2024-08-11 20:27:29,353	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 65, 60, 90, 30)}
# 2024-08-11 20:27:53,469	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 60, 70, 80, 55)}
# 2024-08-11 20:28:24,089	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 55, 30, 40, 35)}
# 2024-08-11 20:28:38,465	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 75, 50, 80, 45)}
# 2024-08-11 20:28:57,875	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 80, 45, 70, 50)}
# 2024-08-11 20:29:17,003	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (65, 75, 35, 90, 40)}
# 2024-08-11 20:29:40,702	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 85, 75, 40, 50)}
# 2024-08-11 20:30:04,729	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (80, 50, 30, 90, 70)}
# 2024-08-11 20:30:55,164	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 75, 55, 85, 40)}
# 2024-08-11 20:31:43,288	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (90, 45, 30, 35, 65)}
# 2024-08-11 20:32:30,322	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (35, 55, 70, 90, 30)}
# 2024-08-11 20:32:55,208	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (55, 90, 60, 85, 75)}
# 2024-08-11 20:33:21,029	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (70, 45, 40, 65, 50)}
# 2024-08-11 20:33:46,384	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 50, 55, 45, 50)}
# 2024-08-11 20:34:11,721	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (50, 65, 80, 45, 45)}
# 2024-08-11 20:34:27,011	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (85, 80, 70, 35, 70)}
# 2024-08-11 20:34:41,607	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (30, 35, 30, 85, 80)}
# 2024-08-11 20:35:07,204	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 35, 80, 75, 30)}
# 2024-08-11 20:35:28,740	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (40, 35, 50, 30, 60)}
# 2024-08-11 20:35:46,523	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (60, 45, 65, 90, 75)}
# 2024-08-11 20:36:13,762	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'hidden_layers': (75, 35, 35, 35, 40)}
# 2024-08-11 20:36:13,893	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/bhanuprasanna/Documents/Uniklinik-Koln/MTL/spike-sorting-multi-task/ray_results/train_and_evaluate_2024-08-11_20-20-59' in 0.1294s.
# 2024-08-11 20:36:13,907	INFO tune.py:1041 -- Total run time: 916.26 seconds (913.78 seconds for the tuning loop).
# Best hyperparameters found were:  {'activation': 'tanh', 'learning_rate': 0.0007873006457324197, 'batch_size': 64, 'hidden_layers': (50, 65, 80, 45, 45), 'epochs': 30, 'dropout_rate': 0.2867625445640953}

# %%
df_dict_A2 = pd.read_pickle("results/output_A2.pkl")
df_dict_A3 = pd.read_pickle("results/output_A3.pkl")
df_dict_A4 = pd.read_pickle("results/output_A4.pkl")
df_dict_A12 = pd.read_pickle("results/output_A12.pkl")
df_dict_A21 = pd.read_pickle("results/output_A21.pkl")

df_dict = pd.concat([df_dict_A2, df_dict_A3, df_dict_A4, df_dict_A12, df_dict_A21])

df_dict = df_dict.loc[:,~df_dict.columns.duplicated()].copy()
df_dict = df_dict.reset_index().rename(columns={'index': 'name'})
df_dict = df_dict.drop_duplicates()

df_dict.to_csv('outputs/Classic_FFN_one_split_metrics_system.csv')

# %%
df_dict_full_A2 = pd.read_pickle("results/output_full_A2.pkl")
df_dict_full_A3 = pd.read_pickle("results/output_full_A3.pkl")
df_dict_full_A4 = pd.read_pickle("results/output_full_A4.pkl")
df_dict_full_A12 = pd.read_pickle("results/output_full_A12.pkl")
df_dict_full_A21 = pd.read_pickle("results/output_full_A21.pkl")

df_full_dict = pd.concat([df_dict_full_A2, df_dict_full_A3, df_dict_full_A4, df_dict_full_A12, df_dict_full_A21])

df_full_dict = df_full_dict.loc[:, ~df_full_dict.columns.duplicated()].copy()
df_full_dict = df_full_dict.reset_index().rename(columns={'index': 'name'})
df_full_dict = df_full_dict.drop_duplicates()

df_full_dict.to_csv("outputs/Classic_FFN_full_split_metrics_system.csv")

# %%
df_dict_full_A2.to_csv("outputs/Classic_FFN_full_split_metrics_A2.csv")
df_dict_full_A3.to_csv("outputs/Classic_FFN_full_split_metrics_A3.csv")
df_dict_full_A4.to_csv("outputs/Classic_FFN_full_split_metrics_A4.csv")
df_dict_full_A12.to_csv("outputs/Classic_FFN_full_split_metrics_A12.csv")
df_dict_full_A21.to_csv("outputs/Classic_FFN_full_split_metrics_A21.csv")

# %%
# print the configs and results for the hyperparemters wiht the highest mean accuracy
# read df_full_dict and print columns with configs in best_params_list_getting
df_full_dict = pd.read_csv("outputs/Classic_FFN_full_split_metrics_system.csv")

if 'Unnamed: 0' in df_full_dict.columns:
    df_full_dict.drop(columns=['Unnamed: 0'], inplace=True)

config_acc_dict = {}
for good_param in best_params_list_getting:
    # get the row witht the highest mean mean accuracy
    mean_accuracy = df_full_dict.loc[df_full_dict['config'] == str(good_param)]['mean_accuracy'].mean()
    config_acc_dict[str(good_param)] = mean_accuracy
    print(f"Mean accuracy for config {good_param} is {mean_accuracy}")

# get the best config
best_config = max(config_acc_dict, key=config_acc_dict.get)
print(f"\n\nThe best config is {best_config} with a mean accuracy of {config_acc_dict[best_config]}")
# Out:
# Mean accuracy for config {'activation': 'tanh', 'learning_rate': 0.0019262652782999904, 'batch_size': 128, 'hidden_layers': (30, 60, 70, 70, 90), 'epochs': 50, 'dropout_rate': 0.2953090215174134} is 0.9459155417099344
# Mean accuracy for config {'activation': 'relu', 'learning_rate': 0.00017299494004745534, 'batch_size': 32, 'hidden_layers': (75, 35, 90, 80, 30), 'epochs': 50, 'dropout_rate': 0.4633289995400754} is 0.916190476190476
# Mean accuracy for config {'activation': 'tanh', 'learning_rate': 0.0007873006457324197, 'batch_size': 64, 'hidden_layers': (50, 65, 80, 45, 45), 'epochs': 30, 'dropout_rate': 0.2867625445640953} is 0.7052650494159928
#
#
# The best config is {'activation': 'tanh', 'learning_rate': 0.0019262652782999904, 'batch_size': 128, 'hidden_layers': (30, 60, 70, 70, 90), 'epochs': 50, 'dropout_rate': 0.2953090215174134} with a mean accuracy of 0.9459155417099344

# %%
best_performers = df_full_dict.loc[df_full_dict.groupby(df_full_dict['name'].str.split('_').str[0])['mean_accuracy'].idxmax()]
best_performers = best_performers.sort_index().reset_index(drop=True)

best_performers
# Out:
#            name  number of classes  min_accuracy  max_accuracy  mean_accuracy  \
# 0   A2_a3a0b998                  2      0.935185      0.953271       0.945916
# 1   A3_bb1cec90                  2      0.884058      0.956522       0.916190
# 2   A4_95d74f4b                  3      0.550761      0.661578       0.619567
# 3  A12_8ba9118b                  6      0.261658      0.310881       0.283122
# 4  A21_efb0e737                  2      0.638095      0.761905       0.705265
#
#    min_f1_macro  max_f1_macro  mean_f1_macro  min_f1_micro  max_f1_micro  \
# 0      0.935135      0.953255       0.945856      0.935185      0.953271
# 1      0.883446      0.956485       0.915995      0.884058      0.956522
# 2      0.542104      0.661916       0.601718      0.550761      0.661578
# 3      0.233558      0.252249       0.239110      0.261658      0.310881
# 4      0.603537      0.717244       0.663985      0.638095      0.761905
#
#    mean_f1_micro   min_mcc   max_mcc  mean_mcc  std_accuracy  std_f1_macro  \
# 0       0.945916  0.871717  0.910595  0.894199      0.006801      0.006809
# 1       0.916190  0.772909  0.916599  0.835965      0.024910      0.025047
# 2       0.619567  0.372373  0.493769  0.455386      0.038669      0.042363
# 3       0.283122  0.120405  0.194506  0.150206      0.019631      0.007089
# 4       0.705265  0.231949  0.509256  0.377413      0.045802      0.039955
#
#    std_f1_micro   std_mcc                                             config
# 0      0.006801  0.013883  {'activation': 'tanh', 'learning_rate': 0.0019...
# 1      0.024910  0.050671  {'activation': 'relu', 'learning_rate': 0.0001...
# 2      0.038669  0.043756  {'activation': 'relu', 'learning_rate': 0.0008...
# 3      0.019631  0.029939  {'activation': 'tanh', 'learning_rate': 0.0002...
# 4      0.045802  0.094095  {'activation': 'tanh', 'learning_rate': 0.0007...
